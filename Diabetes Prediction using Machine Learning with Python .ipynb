# %%
pip install numpy pandas scikit-learn
# Out:
# Collecting numpy
#   Downloading numpy-2.3.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting pandas
#   Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tousif m tamboli\downloads\diabetes-prediction-using-machine-learning-with-python\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.15.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\tousif m tamboli\downloads\diabetes-prediction-using-machine-learning-with-python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading numpy-2.3.0-cp313-cp313-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 4.8 MB/s eta 0:00:03
#    -------------- ------------------------- 4.7/12.7 MB 15.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.7 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 20.5 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----------------------- ---------------- 6.6/11.0 MB 31.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 29.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------- ----------- 7.6/10.7 MB 37.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 36.4 MB/s eta 0:00:00
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.15.3-cp313-cp313-win_amd64.whl (41.0 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    --------------- ------------------------ 3/8 [numpy]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    -------------------- ------------------- 4/8 [joblib]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------- -------------- 5/8 [scipy]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ------------------------------ --------- 6/8 [pandas]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ----------------------------------- ---- 7/8 [scikit-learn]
#    ---------------------------------------- 8/8 [scikit-learn]
#
# Successfully installed joblib-1.5.1 numpy-2.3.0 pandas-2.3.0 pytz-2025.2 scikit-learn-1.7.0 scipy-1.15.3 threadpoolctl-3.6.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis

# %%
diabetes_dataset = pd.read_csv(r"./diabetes.csv")

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
 diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X = diabetes_dataset.drop(columns= "Outcome", axis=1)
Y = diabetes_dataset['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scalar = StandardScaler()

# %%
scalar.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scalar.transform(X)

# %%
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
X = standardized_data
Y = diabetes_dataset['Outcome']

# %%
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
X.shape
# Out:
# (768, 8)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %% [markdown]
# Training the Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
training_data_accuracy
# Out:
# 0.7866449511400652

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
test_data_accuracy
# Out:
# 0.7727272727272727

# %% [markdown]
# Making a Predictive System

# %%
input_data = (1, 89, 66, 23, 94, 28.1, 0.167, 21)

#changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array as we are predicting for one instance 
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

#standardize the input ddiabetes_dataset
std_data = scalar.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print('The person is not diabtic')
else:
    print("The person is diabetic")
# Out:
# [[-0.84488505 -0.99820778 -0.16054575  0.15453319  0.12330164 -0.49404308
#   -0.92076261 -1.04154944]]
# [0]
# The person is not diabtic
# c:\Users\Tousif M Tamboli\Downloads\Diabetes-Prediction-using-Machine-Learning-with-Python\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename = 'diabetes_model.sav'
pickle.dump(classifier, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
input_data = (1, 89, 66, 23, 94, 28.1, 0.167, 21)

input_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = loaded_model.predict(input_data_reshaped)
print(prediction)

if(prediction[0] == 0):
    print('The person is not diabetic')
# Out:
# [1]
